# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()

# %%
df1['A'].plot(kind='hist')

# %%
df1['A'].plot.hist()
# ye mene hist plot kia ha uper 3 alag ways 
# se ye wala sab se best ha

# %%
df2.plot.area(alpha=0.4)
# alpha transparency batane ke lye use krte

# %%
df2.plot.bar(stacked=True)
# index val ko as a cat leta ha so as a cat it will list down each val for a col
# stacked se har cat ka bar ek dusre pe agya

# %%
# df1.plot.line(x=df1.index , y="b")
df1.plot.scatter(x='A',y='B',c='C')
# yhan ab ek trh se 3d graph plot krdya ha jisme ek tu ma AvB
# plot krrha or dusra C ko as a color plot kr rha

df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# ab yhan mene AvB plot kia or C ko 100 se * krwake plot krwaya ke wu AvB ke relative kitni bari ha
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()
# this take every col as a cat n plots the dist for us

# %%
df2['a'].plot.kde()
# hexbin b bana skte pandas se

# if u want to compare kde for all the col in your data set
df2.plot.kde()
